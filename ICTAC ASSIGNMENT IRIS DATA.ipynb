# %% [markdown]
# ## 1. Read the dataset to python environment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
iris_df=pd.read_excel('iris.xls')
##first 5 lines
iris_df.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# ##### Printing the full data set

# %%
print(iris_df)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##### To show the shape of the data set (Numbrt of rows and columns)

# %%
print(iris_df.shape)
# Out:
# (150, 5)

# %% [markdown]
# ##### Shows the row index starts in 0 ends in 150

# %%
print(iris_df.index)
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %% [markdown]
# ## 2. Display the columns in the dataset.

# %%
print(iris_df.columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
print(iris_df.describe)
# Out:
# <bound method NDFrame.describe of       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %% [markdown]
# ## 3. Calculate the mean of each column of the dataset.

# %%
print(df.mean())
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## 4.Check for the null values present in the dataset.

# %% [markdown]
# ##### Info here shows that in all 150 rows there are only non-null objects

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ##### To double check a Boolean is run over the df and sum of null values is taken in the next step

# %%
iris_df.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
iris_df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# #### No null values present

# %% [markdown]
# ##### Classification tab is removed to show the correlation

# %%
df=iris_df.drop(columns=['Classification'])
print(df)
# Out:
#       SL   SW   PL   PW
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
df.corr()
# Out:
#           SL        SW        PL        PW
# SL  1.000000 -0.109369  0.871754  0.817954
# SW -0.109369  1.000000 -0.420516 -0.356544
# PL  0.871754 -0.420516  1.000000  0.962757
# PW  0.817954 -0.356544  0.962757  1.000000

# %% [markdown]
# ## 5.Perform meaningful visualizations using the dataset. Bring at least 3

# %% [markdown]
# ##### Bar graph showing the number of each classification present

# %%
sns.countplot(x='Classification', data=iris_df )
plt.show()

# %% [markdown]
# The data set contains information about Iris Flower and it contains 3 of its species-Setosa , Versicolor , Virginica

# %% [markdown]
# The graphs below are scatter plots betweem the respectice Sepal and Petal Lengths and Widths

# %%
sns.scatterplot(x='SL',y='SW',data=iris_df,hue='Classification')
print(plt.show())
# Out:
# None

# %%
sns.scatterplot(x='SL',y='PL',data=iris_df,hue='Classification')
print(plt.show())
# Out:
# None

# %%
sns.scatterplot(x='PL',y='PW',data=iris_df,hue='Classification')
print(plt.show())
# Out:
# None

# %%
Pairplot of the iris data frame

# %%
sns.pairplot(iris_df,hue='Classification')
print(plt.show)
# Out:
# <function show at 0x0000023FD137C310>

# %% [markdown]
# 1. Seotsa has the smallest of petals widths and lengths
# 2. Virginica has the largest Sepal and Petal Lengths
# 3. Versicolor almost always comes between the other two species in terms of both Petal and Sepal lengths and widths

# %% [markdown]
# Histograms of SL,PL,SW and PW

# %%
sns.histplot(iris_df['SL'])
print(plt.show)
# Out:
# <function show at 0x0000023FD137C310>

# %%
sns.histplot(iris_df['PL'])
print(plt.show)
# Out:
# <function show at 0x0000023FD137C310>

# %%
sns.histplot(iris_df['SW'])
print(plt.show)
# Out:
# <function show at 0x0000023FD137C310>

# %%
sns.histplot(iris_df['PW'])
print(plt.show)
# Out:
# <function show at 0x0000023FD137C310>

# %% [markdown]
# Violin chart of the data set

# %%
print(df.mean())
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
plt.figure(figsize=(14,6))
sns.violinplot(data=df)
print(plt.show())
# Out:
# None

# %% [markdown]
# 1. Average of SL is 5.8 and the distribution is almost evenly spread in the range of 4.5 to 6.2
# 2. Average of SW is 3.1 and almost all the data in Sepal width can be found near the average value
# 3. Average of PL is 3.8 and is distributed largely near the values 1.5 and 4 which are the First and Third Quartile.
# 4. Average of PL is 1.1 and the distribution is similar to the Petal length amd is largely distributed in the First and Third Quartile.

# %% [markdown]
# Box plot of the data frame

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=df)
print(plt.show())
# Out:
# None
